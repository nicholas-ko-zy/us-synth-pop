# %%
# Convert this project to use renv
renv::init()
# Out:
# - Linking packages into the project library ... [41/68[42/68[43/68[44/68[45/68[46/68[47/68[48/68[49/68[50/68[51/68[52/68[53/68[54/68[55/68[56/68[57/68[58/68[59/68[60/68[61/68[62/68[63/68[64/68[65/68[66/68[67/68[68/68] Done!
# - Resolving missing dependencies ...
# - Querying repositories for available source packages ... Done!
# # Downloading packages -------------------------------------------------------
# ✔ selectr 0.5-1                            [55 kB in 1.4s]
# ✔ cachem 1.1.0                             [27 kB in 1.4s]
# ✔ png 0.1-9                                [25 kB in 1.5s]
# ✔ clipr 0.8.1                              [21 kB in 1.5s]
# ✔ xml2 1.5.2                               [155 kB in 1.5s]
# ✔ bit64 4.8.2                              [172 kB in 1.5s]
# ✔ spacesXYZ 1.6-0                          [243 kB in 1.5s]
# ✔ knitr 1.51                               [484 kB in 1.5s]
# ✔ httr 1.4.8                               [114 kB in 0.1s]
# ...
